# %%
import os
from dotenv import load_dotenv
load_dotenv()


os.environ['HF_TOKEN']=os.getenv('HF_TOKEN')
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2']="true"

# %%
pip install openai
# Out:
# Collecting openai
#   Using cached openai-1.58.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.7.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Using cached jiter-0.8.2-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.10.4)
# Requirement already satisfied: sniffio in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\gupta\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\gupta\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-1.58.1-py3-none-any.whl (454 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.8.2-cp312-cp312-win_amd64.whl (204 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, jiter, distro, openai
# Successfully installed distro-1.9.0 jiter-0.8.2 openai-1.58.1 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from langchain_openai import ChatOpenAI

client = OpenAI(
	base_url="https://api-inference.huggingface.co/v1/",
	api_key=os.environ['HF_TOKEN']
)

messages = [
	{ "role": "user", "content": "Tell me a story" }
]

llm = client.chat.completions.create(
    model="mistralai/Mixtral-8x7B-Instruct-v0.1", 
	messages=messages, 
	temperature=0.5,
	max_tokens=2048,
	top_p=0.7,
	stream=True
)
for chunk in llm:
    print(chunk.choices[0].delta.content)
# Out:
#  Once
#  upon
#  a
#  time
# ,
#  in
#  a
#  land
#  far
# ,
#  far
#  away
# ,
#  there
#  was
#  a
#  small
# ,
#  peaceful
#  village
#  nest
# led
#  in
#  the
#  heart
#  of
#  a
#  l
# ush
# ,
#  green
#  forest
# .
#  The
#  village
#  was
#  home
#  to
#  a
#  close
# -
# kn
# it
#  community
#  of
#  kind
# ,
#  hard
# working
#  people
#  who
#  lived
#  in
#  harmony
#  with
#  nature
# .
#
#
#
#
# In
#  the
#  village
# ,
#  there
#  lived
#  a
#  young
#  girl
#  named
#  Lily
# .
#  Lily
#  was
#  a
#  curious
#  and
#  advent
# ur
# ous
#  child
# ,
#  with
#  a
#  heart
#  full
#  of
#  wonder
#  and
#  a
#  mind
#  full
#  of
#  questions
# .
#  She
#  spent
#  her
#  days
#  exploring
#  the
#  forest
# ,
#  discover
# ing
#  new
#  secrets
#  and
#  making
#  friends
#  with
#  the
#  animals
#  who
#  lived
#  there
# .
#
#
#
#
# One
#  day
# ,
#  while
#  Lily
#  was
#  out
#  exploring
# ,
#  she
#  stumbled
#  upon
#  a
#  hidden
#  clearing
#  in
#  the
#  forest
# .
#  In
#  the
#  center
#  of
#  the
#  clearing
# ,
#  there
#  was
#  a
#  beautiful
# ,
#  sh
# immer
# ing
#  p
# ond
# ,
#  fed
#  by
#  a
#  crystal
# -
# clear
#  stream
# .
#  Lily
#  had
#  never
#  seen
#  anything
#  so
#  magical
#  and
#  en
# chant
# ing
# ,
#  and
#  she
#  knew
#  that
#  she
#  had
#  to
#  share
#  it
#  with
#  her
#  village
# .
#
#
#
#
# So
# ,
#  Lily
#  ran
#  back
#  to
#  her
#  village
# ,
#  her
#  heart
#  pound
# ing
#  with
#  excitement
# ,
#  and
#  told
#  everyone
#  about
#  the
#  magical
#  p
# ond
#  she
#  had
#  discovered
# .
#  The
#  vill
# agers
#  were
#  amaz
# ed
#  and
#  grateful
# ,
#  and
#  they
#  decided
#  to
#  make
#  a
#  special
#  pil
# gr
# image
#  to
#  the
#  p
# ond
#  to
#  give
#  thanks
#  for
#  its
#  beauty
#  and
#  wonder
# .
#
#
#
#
# From
#  that
#  day
#  on
# ,
#  the
#  magical
#  p
# ond
#  became
#  a
#  sacred
#  place
#  for
#  the
#  vill
# agers
# ,
#  a
#  place
#  where
#  they
#  could
#  come
#  to
#  pray
# ,
#  med
# itate
# ,
#  and
#  connect
#  with
#  the
#  natural
#  world
# .
#  And
#  Lily
# ,
#  who
#  had
#  discovered
#  the
#  p
# ond
# ,
#  became
#  known
#  as
#  the
#  village
# '
# s
#  greatest
#  treasure
# ,
#  a
#  symbol
#  of
#  curiosity
# ,
#  adventure
# ,
#  and
#  the
#  power
#  of
#  discovery
# .
#
#
#
#
# The
#  end
# .
